# %%
filefolder = "/Users/gracekim/Downloads"

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
fig,ax = plt.subplots(1,1,figsize = (12,6))
SMALL_SIZE = 8
MEDIUM_SIZE = 16
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

SMALL_SIZE = 8
matplotlib.rc('font', size=MEDIUM_SIZE)
matplotlib.rc('axes', titlesize=BIGGER_SIZE)
matplotlib.rc('axes', labelsize=MEDIUM_SIZE)

Id = pd.read_csv("/Users/gracekim/Downloads/L46.csv")
label = []
for i in range(9):
    label.append([Id['Id'][i][-1],Id['parameters/Gamma'][i]])

print(label)

for i in range(9):
    test = pd.read_csv("/Users/gracekim/Downloads/floatSeries_multi/L-14"+str(i)+"__train_episode_durations.csv")
    plt.plot(test.iloc[:,0],test.iloc[:,2],label = label[8-i][1])
plt.legend()
plt.xlabel("Number of Episodes Run")
plt.ylabel("Number of Steps Pole Balanced in Sim")
plt.title("Effect of Gamma Values on DQN Training for Cart Pole Simulation")

# plt.
# Out:
# [['8', 0.6], ['7', 0.7], ['6', 0.8], ['5', 0.05], ['4', 0.1], ['3', 0.2], ['2', 0.5], ['1', 0.9], ['0', 0.99]]
# Text(0.5, 1.0, 'Effect of Gamma Values on DQN Training for Cart Pole Simulation')

# %%
fig,ax = plt.subplots(1,1,figsize = (12,6))

Id = pd.read_csv("/Users/gracekim/Downloads/L46 _eps_start.csv")
label = []
for i in range(5):
    label.append([Id['Id'][i][-1],Id['parameters/EPS_START'][i]])

print(label)

for i in range(3,8):
    test = pd.read_csv("/Users/gracekim/Downloads/floatSeries_multi_eps_start/L-13"+str(i)+"__train_episode_durations.csv")
    plt.plot(test.iloc[:,0],test.iloc[:,2],label = label[7-i][1])
plt.legend()
plt.xlabel("Number of Episodes Run")
plt.ylabel("Number of Steps Pole Balanced in Sim")
plt.title("Effect of EPS_START Values on DQN Training for Cart Pole Simulation")
# Out:
# [['7', 0.05], ['6', 0.1], ['5', 0.2], ['4', 0.5], ['3', 0.9]]
# Text(0.5, 1.0, 'Effect of EPS_START Values on DQN Training for Cart Pole Simulation')

# %%
fig,ax = plt.subplots(1,1,figsize = (12,6))

Id = pd.read_csv("/Users/gracekim/Downloads/L46_eps_end.csv")
label = []
for i in range(4):
    label.append([Id['Id'][i+1][-1],Id['parameters/EPS_END'][i+1]])
label.append([Id['Id'][0][-1],Id['parameters/EPS_END'][0]])

print(label)

for i in range(5,10):
    test = pd.read_csv("/Users/gracekim/Downloads/floatSeries_multi_eps_end/L-12"+str(i)+"__train_episode_durations.csv")
    plt.plot(test.iloc[:,0],test.iloc[:,2],label = label[9-i][1])
plt.legend()
plt.xlabel("Number of Episodes Run")
plt.ylabel("Number of Steps Pole Balanced in Sim")
plt.title("Effect of EPS_END Values on DQN Training for Cart Pole Simulation")
# plt.
# Out:
# [['9', 0.1], ['8', 0.2], ['7', 0.5], ['6', 0.9], ['0', 0.05]]
# Text(0.5, 1.0, 'Effect of EPS_END Values on DQN Training for Cart Pole Simulation')

# %%
fig,ax = plt.subplots(1,1,figsize = (12,6))

Id = pd.read_csv("/Users/gracekim/Downloads/L46_LR.csv")
label = []
for i in range(5):
    label.append([Id['Id'][i][-3:],Id['parameters/Learning Rate'][i]])

print(label)

for i in label:
    test = pd.read_csv("/Users/gracekim/Downloads/floatSeries_multi_LR/L-"+str(i[0])+"__train_episode_durations.csv")
    plt.plot(test.iloc[:,0],test.iloc[:,2],label = i[1],zorder = int(i[0]))
plt.legend()
plt.xlabel("Number of Episodes Run")
plt.ylabel("Number of Steps Pole Balanced in Sim")
plt.title("Effect of Learning Rates on DQN Training for Cart Pole Simulation")
# plt.
# Out:
# [['132', 1e-05], ['131', 0.0001], ['121', 0.001], ['120', 0.01], ['119', 0.1]]
# Text(0.5, 1.0, 'Effect of Learning Rates on DQN Training for Cart Pole Simulation')

# %%
label
# Out:
# [['9', 0.9], ['8', 0.9], ['7', 0.9], ['6', 0.9], ['0', 0.9]]

# %%
x = [[-0.15896402299404144, -0.9648182392120361, 0.17703132331371307, 1.5065996646881104]]

# %%
id =  pd.read_csv("/Users/gracekim/Downloads/L46_hardware_prob.csv")
id.columns
# Out:
# Index(['Id', 'Creation Time', 'parameters/Test Name',
#        'parameters/Learning Rate', 'parameters/Gamma', 'parameters/EPS_START',
#        'parameters/EPS_END', 'Owner', 'Tags',
#        'train/episode_durations (average)',
#        'parameters/hardware problem response'],
#       dtype='object')

# %%
fig,ax = plt.subplots(1,1,figsize = (12,6))

Id = pd.read_csv("/Users/gracekim/Downloads/L46_hardware_prob.csv")
label = []
for i in range(6):
    label.append([Id['Id'][i][-3:],Id['parameters/hardware problem response'][i]])

print(label)

for i in label:
    test = pd.read_csv("/Users/gracekim/Downloads/floatSeries_multi_hardware_prob_angle/L-"+str(i[0])+"__last_run_log_state_angle.csv")
    plt.plot(test.iloc[:,0],test.iloc[:,2],label = "Delay of steps in response from simulation: " + str(i[1]),zorder = int(i[0]))
plt.legend()
plt.xlabel("Number of Steps")
plt.ylabel("Angle of Pole in Radians")
plt.title("Simulations of Angle states for policies with latency in Sensor Communication")
# plt.
# Out:
# [['157', 0], ['156', 1], ['155', 2], ['154', 3], ['153', 4], ['152', 5]]
# Text(0.5, 1.0, 'Simulations of Angle states for policies with latency in Sensor Communication')

# %%
fig,ax = plt.subplots(1,1,figsize = (12,6))

Id = pd.read_csv("/Users/gracekim/Downloads/L46_hardware_prob.csv")
label = []
for i in range(6):
    label.append([Id['Id'][i][-3:],Id['parameters/hardware problem response'][i]])

print(label)

for i in label:
    test = pd.read_csv("/Users/gracekim/Downloads/floatSeries_multi_hardware_prob_episode/L-"+str(i[0])+"__train_episode_durations.csv")
    plt.plot(test.iloc[:,0],test.iloc[:,2],label ="Delay of steps in response from simulation: " + str(i[1]),zorder = int(i[0]))
plt.legend()
plt.xlabel("Number of Episodes Run")
plt.ylabel("Number of Steps Pole Balanced in Sim")
plt.title("Episode Durations for policies with latency in Sensor Communication")
# plt.
# Out:
# [['157', 0], ['156', 1], ['155', 2], ['154', 3], ['153', 4], ['152', 5]]
# Text(0.5, 1.0, 'Episode Durations for policies with latency in Sensor Communication')

# %%
fig,ax = plt.subplots(1,1,figsize = (10,6))

Id = pd.read_csv("/Users/gracekim/Downloads/L46_end_test.csv")
label = []
for i in range(4):
    label.append([Id['Id'][i][-3:],Id['parameters/edge_limit'][i]])

print(label)


for i in label:
    test = pd.read_csv("/Users/gracekim/Downloads/floatSeries_multi_end_test_episode/L-"+str(i[0])+"__train_episode_durations.csv")
    plt.plot(test.iloc[:,0],test.iloc[:,2],label ="Movement limit (m): " + str(i[1]),zorder = int(i[0]))
plt.legend()
plt.xlabel("Number of Episodes Run")
plt.ylabel("Number of Steps Pole Balanced in Sim")
plt.title("Episode Durations for policies with limit in x_movement")
# plt.
# Out:
# [['176', 1.2], ['175', 0.6], ['174', 0.3], ['160', 2.4]]
# Text(0.5, 1.0, 'Episode Durations for policies with limit in x_movement')

# %%
fig,ax = plt.subplots(1,1,figsize = (10,6))

Id = pd.read_csv("/Users/gracekim/Downloads/L46_end_test.csv")
label = []
for i in range(4):
    label.append([Id['Id'][i][-3:],Id['parameters/edge_limit'][i]])

print(label)


for i in label:
    test = pd.read_csv("/Users/gracekim/Downloads/floatSeries_multi_end_test_x/L-"+str(i[0])+"__last_run_log_state_position.csv")
    plt.plot(test.iloc[:,0],test.iloc[:,2],label ="Movement limit (m): " + str(i[1]),zorder = int(i[0]))
plt.legend()
plt.xlabel("Number of Steps Run")
plt.ylabel("Position in x (m)")
plt.title("Simulations of X positions for policies with limit in x_movement")
# plt.
# Out:
# [['176', 1.2], ['175', 0.6], ['174', 0.3], ['160', 2.4]]
# Text(0.5, 1.0, 'Simulations of X positions for policies with limit in x_movement')

# %%
fig,ax = plt.subplots(1,1,figsize = (10,6))

import numpy as np
Id = pd.read_csv("/Users/gracekim/Downloads/L46_sensor.csv")
label = []
for i in range(6):
    a = [Id['Id'][i][-3:],Id['parameters/Random_Gen'][i]]
    b = [Id['Id'][i][-3:],Id['parameters/Random_Gen.1'][i]]
    if np.isnan(a[1]):
        label.append(b)
    else:
        label.append(a)

print(label)


for i in label:
    test = pd.read_csv("/Users/gracekim/Downloads/floatSeries_multi_sensor/L-"+str(i[0])+"__last_run_log_state_angle.csv")
    plt.plot(test.iloc[:,0],test.iloc[:,2],label ="Sensor random error mean (deg): " + str(i[1]),zorder = int(i[0]))
plt.legend()
plt.xlabel("Number of Steps Run")
plt.ylabel("Angle in (rad)")
plt.title("Simulations of Angle positions for policies with randomized sensor error")
# plt.
# Out:
# [['171', 10.0], ['170', 5.0], ['169', 1.0], ['168', 0.5], ['167', 0.05], ['166', 0.0]]
# Text(0.5, 1.0, 'Simulations of Angle positions for policies with randomized sensor error')

# %%
fig,ax = plt.subplots(1,1,figsize = (10,6))

import numpy as np
Id = pd.read_csv("/Users/gracekim/Downloads/L46_sensor.csv")
label = []
for i in range(6):
    a = [Id['Id'][i][-3:],Id['parameters/Random_Gen'][i]]
    b = [Id['Id'][i][-3:],Id['parameters/Random_Gen.1'][i]]
    if np.isnan(a[1]):
        label.append(b)
    else:
        label.append(a)

print(label)


for i in label:
    test = pd.read_csv("/Users/gracekim/Downloads/floatSeries_multi_sensor_episode/L-"+str(i[0])+"__train_episode_durations.csv")
    plt.plot(test.iloc[:,0],test.iloc[:,2],label ="Sensor random error mean (deg): " + str(i[1]),zorder = int(i[0]))
plt.legend()
plt.xlabel("Number of Episodes Run")
plt.ylabel("Number of Steps Pole Balanced in Sim")
plt.title("Episode Durations for policies with randomized sensor error")
# plt.
# Out:
# [['171', 10.0], ['170', 5.0], ['169', 1.0], ['168', 0.5], ['167', 0.05], ['166', 0.0]]
# Text(0.5, 1.0, 'Episode Durations for policies with randomized sensor error')

# %%
fig,ax = plt.subplots(1,1,figsize = (10,6))

import numpy as np
Id = pd.read_csv("/Users/gracekim/Downloads/L46 (1).csv")
label = []
for i in range(6):
    a = [Id['Id'][i][-3:],Id['parameters/Random_Gen'][i]]
    b = [Id['Id'][i][-3:],Id['parameters/Random_Gen.1'][i]]
    if np.isnan(a[1]):
        label.append(b)
    else:
        label.append(a)

print(label)

Id2= pd.read_csv("/Users/gracekim/Downloads/L46 (2).csv")
label2 = []
for i in range(9):
    a = [Id2['Id'][i][-3:],Id2['parameters/Random_Gen'][i]]
    b = [Id2['Id'][i][-3:],Id2['parameters/Random_Gen.1'][i]]
    if np.isnan(a[1]):
        label2.append(b)
    else:
        label2.append(a)

print(label2)


for i in label:
    if i[0] != "173" and i[0] != "-74":
        test = pd.read_csv("/Users/gracekim/Downloads/floatSeries_multi (2)/L-"+str(i[0])+"__last_run_log_state_angle.csv")
        plt.plot(test.iloc[:,0],test.iloc[:,2])#,color = "blue", alpha = (int(i[0])-100)/100)
for i in label2:
    if i[0] != "103" and i[0] != "-74":
        test = pd.read_csv("/Users/gracekim/Downloads/floatSeries_multi (4)/L-"+str(i[0])+"__last_run_log_state_angle.csv")
        plt.plot(test.iloc[:,0],test.iloc[:,2])#,color = "red",alpha = (int(i[0])-100)/10)
# plt.legend(["Modified Simulation", "Unmodified Simulation"])
plt.ylim(-0.4,0.4)
plt.xlabel("Number of Steps")
plt.ylabel("Pole Angle in Radians")
plt.title("Trial Runs of Modified Simulations onto hardware")
# plt.
# Out:
# [['178', 0.05], ['176', nan], ['175', nan], ['173', nan], ['106', nan], ['-74', nan]]
# [['108', nan], ['107', nan], ['106', nan], ['105', nan], ['104', nan], ['103', nan], ['102', nan], ['101', nan], ['100', nan]]
# Text(0.5, 1.0, 'Trial Runs of Modified Simulations onto hardware')

# %%
fig,ax = plt.subplots(1,1,figsize = (10,6))

import numpy as np
Id = pd.read_csv("/Users/gracekim/Downloads/L46 (1).csv")
label = []
for i in range(6):
    a = [Id['Id'][i][-3:],Id['parameters/Random_Gen'][i]]
    b = [Id['Id'][i][-3:],Id['parameters/Random_Gen.1'][i]]
    if np.isnan(a[1]):
        label.append(b)
    else:
        label.append(a)

print(label)

Id2= pd.read_csv("/Users/gracekim/Downloads/L46 (2).csv")
label2 = []
for i in range(9):
    a = [Id2['Id'][i][-3:],Id2['parameters/Random_Gen'][i]]
    b = [Id2['Id'][i][-3:],Id2['parameters/Random_Gen.1'][i]]
    if np.isnan(a[1]):
        label2.append(b)
    else:
        label2.append(a)

print(label2)


for i in label:
    if i[0] != "173" and i[0] != "-74":
        test = pd.read_csv("/Users/gracekim/Downloads/floatSeries_multi (3)/L-"+str(i[0])+"__last_run_log_state_position.csv")
        plt.plot(test.iloc[:,0],test.iloc[:,2])#,color = "blue", alpha = (int(i[0])-100)/100)
for i in label2:
    if i[0] != "103" and i[0] != "-74":
        test = pd.read_csv("/Users/gracekim/Downloads/floatSeries_multi (5)/L-"+str(i[0])+"__last_run_log_state_position.csv")
        plt.plot(test.iloc[:,0],test.iloc[:,2])#,color = "red",alpha = (int(i[0])-100)/10)
# plt.legend(["Modified Simulation", "Unmodified Simulation"])
# plt.ylim(-0.4,0.4)
plt.xlabel("Number of Steps")
plt.ylabel("Cart Position in x")
plt.title("Trial Runs of Modified Simulations onto hardware")
# plt.
# Out:
# [['178', 0.05], ['176', nan], ['175', nan], ['173', nan], ['106', nan], ['-74', nan]]
# [['108', nan], ['107', nan], ['106', nan], ['105', nan], ['104', nan], ['103', nan], ['102', nan], ['101', nan], ['100', nan]]
# Text(0.5, 1.0, 'Trial Runs of Modified Simulations onto hardware')

# %%
fig,ax = plt.subplots(1,1,figsize = (10,6))

test = pd.read_csv("/Users/gracekim/Downloads/train_episode_durations.csv")
plt.plot(test.iloc[:,0]*2,test.iloc[:,2]/1.5)#,color = "blue", alpha = (int(i[0])-100)/100)

plt.xlabel("Number of Episodes")
plt.ylabel("Number of Steps in each Episode")
plt.title("Episode Durations for policies trained with additional latency, sensor error, x_limits")
# Out:
# Text(0.5, 1.0, 'Episode Durations for policies trained with additional latency, sensor error, x_limits')
